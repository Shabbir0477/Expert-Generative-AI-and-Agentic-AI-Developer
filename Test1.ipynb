# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabbir0477/Expert-Generative-AI-and-Agentic-AI-Developer/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1: work with numbers

# %%
5
# Out:
# 5

# %%
5+6+7
# Out:
# 18

# %% [markdown]
# BODMAS(Bracket,order,division,multiplication, Addition, Sub

# %% [markdown]
# # Work with String

# %%
'Hello'
# Out:
# 'Hello'

# %%
"hello world"
# Out:
# 'hello world'

# %%
'''Hello world

This is shabbir'''
# Out:
# 'Hello world\n\nThis is shabbir'
